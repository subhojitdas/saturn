# %%
import numpy as np
import pandas as pd

import os, sys

import torch.nn.functional
import torch.nn.functional as F

project_root = os.path.abspath('/Users/subhojit/workspace/saturn/src')
if project_root not in sys.path:
    sys.path.append(project_root)

from lstm_att.lstm_attention import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset_dir = '/Users/subhojit/datasets/amazon_review_polarity_csv'
df = pd.read_csv(dataset_dir + '/train.csv')
df.head()

df_test = pd.read_csv(dataset_dir + '/test.csv')

# %%
review = df.iloc[:, 2].to_numpy()
test_review = df_test.iloc[:, 2].to_numpy()

all_review = np.concatenate((review, test_review))
c = sorted(list(set(''.join(all_review))))
chars = c + ['<SOS>', '<EOS>', '<PAD>']
stoi = {ch:i for i, ch in enumerate(chars)}
itos = {i:ch for i, ch in enumerate(chars)}
vocab_size = len(chars)
# vocab_size, stoi

# %%
x = df.iloc[:, 2].to_numpy()
y = df.iloc[:, 0].to_numpy()
n = int(0.9*len(x))
xtrain = x[:n]
ytrain = y[:n]
xval = x[n:]
yval = y[n:]

xtest = df_test.iloc[:, 2].to_numpy()
ytest = df_test.iloc[:, 0].to_numpy()

# %%
stoi = {ch:i for i, ch in enumerate(chars)}
itos = {i:ch for i, ch in enumerate(chars)}
encode = lambda s: [stoi[xi] for xi in s]
decode = lambda l: ''.join([itos[li] for li in l])
encode('asdasdsadas')

# %%
# if torch.backends.mps.is_available():
#     device = "mps"
# elif torch.cuda.is_available():
#     device = "cuda"
# else:
#     device = "cpu"

device="cpu"

# %%
def pad_sequences(sequences):
    pad_index = stoi['<PAD>']
    max_len = np.max([len(s) for s in sequences])
    padded_seq = np.full((len(sequences), max_len), pad_index, dtype=np.int32)
    for i, seq in enumerate(sequences):
        padded_seq[i, :len(seq)] = seq
    return padded_seq


def get_batch(batch_size, split='train'):
    data = xtrain if split == 'train' else xval
    target = ytrain if split == 'train' else yval
    idx = np.random.randint(0, len(data), (batch_size,))
    x_sample = [encode(s) for s in data[idx]]
    y_sample = target[idx]
    xpadded = pad_sequences(x_sample)
    xb, yb = xpadded, y_sample
    yb = torch.from_numpy(yb)
    yb = yb - 1
    # yb = torch.nn.functional.one_hot(yb - 1, num_classes=2)
    xb = torch.from_numpy(xb)
    x = xb.to(device, dtype=torch.long)
    y = yb.to(device, dtype=torch.long)
    return x, y

batch_size = 32

xb, yb = get_batch(batch_size)

# %%
def create_mask(padded_batch):
    pad_index = stoi['<PAD>']
    return (padded_batch != pad_index).astype(np.float32)

# %%
# training with LSTM with attention
embedding_dim = 32
hidden_size = 64
output_size = 2
batch_size = 64
seq_len = 10
learning_rate = 1e-2
max_iter = 5000
eval_interval = 500

model = LSTMWithAttention(vocab_size, hidden_size, output_size, embedding_dim)
model = model.to(device)

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for step in range(max_iter):
    xb, yb = get_batch(batch_size)
    logits = model(xb)
    loss = F.cross_entropy(logits, yb)
    optimizer.zero_grad()
    loss.backward()
    # print("grad norm:", model.fc.weight.grad.norm())
    # print("Input device:", xb.device)
    # print("Output device:", yb.device)
    # print("Model device:", next(model.parameters()).device)
    # print("Logits device:", logits.device)

    print("xb shape: ", xb.shape)  # should be (batch_size, seq_len)
    print("xb dtype: ", xb.dtype)
    print("yb shape: ", yb.shape)  # should be (batch_size,)
    print("yb dtype: ", yb.dtype)  # should be torch.long
    print("logits shape: ", logits.shape)  # should be (batch_size, 2)

    # print("Loss:", loss.item())
    optimizer.step()
    if step % eval_interval == 0:
        print(f"step {step}: train loss {loss:.4f}")
        with torch.no_grad():
            logits = model(xb)
            probs = torch.softmax(logits, dim=1)
            print("Confidence range:", probs.max(dim=1).values[:10])
            preds = torch.argmax(logits, dim=1)
            print("Preds: ", preds.tolist())
            print("Targets: ", yb.tolist())

# %%
def get_val_batches():
    iter = len(xval) // batch_size
    for i in range(iter):
        idx = torch.arange(i * batch_size, (i + 1) * batch_size)
        x_sample = [encode(s) for s in xval[idx]]
        y_sample = yval[idx]
        xpadded = pad_sequences(x_sample)
        xb, yb = np.vstack(xpadded), y_sample
        yb = torch.from_numpy(yb)
        yb = torch.nn.functional.one_hot(yb - 1, num_classes=2)
        xb = torch.from_numpy(xb)
        x = xb.to(device)
        y = yb.to(device)
        yield x, y


@torch.no_grad()
def compute_accuracy():
    out = {}
    model.eval()
    correct = 0
    total = 0
    for X, Y in get_val_batches():
        logits = model(X)
        preds = torch.argmax(logits, dim=1)
        correct += (preds == Y).all(dim=1).sum().item()
        total += Y.shape[0]
    acc = (correct / total)
    return acc

val_acc = compute_accuracy()
print(f"Validation Accuracy: {val_acc * 100:.2f}%")

# %%
device = torch.device("cpu")
model = model.to(device)
xb, yb = get_batch(4)
xb = xb.to(device)
yb = yb.to(device)

# %%
# one batch overfitting
model = LSTMWithAttention(vocab_size, hidden_size, output_size, embedding_dim)

xb, yb = get_batch(64)
# xb, yb = xb.to(device), yb.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-2)

for step in range(1000):
    print("Input:", xb.shape, xb.dtype, xb.device)
    print("Target:", yb.shape, yb.dtype, yb.device)
    logits = model(xb)
    loss = F.cross_entropy(logits, yb)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print(f"Step {step}, loss = {loss.item():.4f}")
    if step % 100 == 0:
        print("Logits:", logits[:2])
# Out:
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 0, loss = 0.6931
# Logits: tensor([[-0.0887,  0.0359],
#         [-0.0887,  0.0359]], grad_fn=<SliceBackward0>)
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 1, loss = 1.3203
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 2, loss = 0.7389
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 3, loss = 0.7239
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 4, loss = 0.7569
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 5, loss = 0.7332
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 6, loss = 0.7067
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 7, loss = 0.6893
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 8, loss = 0.6803
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 9, loss = 0.6777
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 10, loss = 0.6791
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 11, loss = 0.6811
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 12, loss = 0.6818
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 13, loss = 0.6811
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 14, loss = 0.6795
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 15, loss = 0.6779
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 16, loss = 0.6765
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 17, loss = 0.6755
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 18, loss = 0.6748
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 19, loss = 0.6745
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 20, loss = 0.6743
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 21, loss = 0.6743
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 22, loss = 0.6743
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 23, loss = 0.6743
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 24, loss = 0.6742
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 25, loss = 0.6741
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 26, loss = 0.6740
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 27, loss = 0.6739
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 28, loss = 0.6737
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 29, loss = 0.6735
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 30, loss = 0.6733
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 31, loss = 0.6731
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 32, loss = 0.6730
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 33, loss = 0.6728
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 34, loss = 0.6727
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 35, loss = 0.6726
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 36, loss = 0.6726
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 37, loss = 0.6725
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 38, loss = 0.6725
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 39, loss = 0.6725
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 40, loss = 0.6725
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 41, loss = 0.6725
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 42, loss = 0.6726
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 43, loss = 0.6725
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 44, loss = 0.6725
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 45, loss = 0.6725
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 46, loss = 0.6725
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 47, loss = 0.6724
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 48, loss = 0.6724
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 49, loss = 0.6724
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 50, loss = 0.6724
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 51, loss = 0.6724
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 52, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 53, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 54, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 55, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 56, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 57, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 58, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 59, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 60, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 61, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 62, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 63, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 64, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 65, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 66, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 67, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 68, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 69, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 70, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 71, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 72, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 73, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 74, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 75, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 76, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 77, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 78, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 79, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 80, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 81, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 82, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 83, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 84, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 85, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 86, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 87, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 88, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 89, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 90, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 91, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 92, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 93, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 94, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 95, loss = 0.6723
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 96, loss = 0.6722
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 97, loss = 0.6722
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 98, loss = 0.6722
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 99, loss = 0.6722
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 100, loss = 0.6722
# Logits: tensor([[-0.1546,  0.1349],
#         [-0.1546,  0.1349]], grad_fn=<SliceBackward0>)
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 101, loss = 0.6722
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 102, loss = 0.6721
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 103, loss = 0.6721
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 104, loss = 0.6720
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 105, loss = 0.6719
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 106, loss = 0.6716
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 107, loss = 0.6710
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 108, loss = 0.6700
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 109, loss = 0.6683
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 110, loss = 0.6651
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 111, loss = 0.6611
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 112, loss = 0.6592
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 113, loss = 0.6581
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 114, loss = 0.6568
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 115, loss = 0.6560
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 116, loss = 0.6555
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 117, loss = 0.6552
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 118, loss = 0.6551
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 119, loss = 0.6549
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 120, loss = 0.6549
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 121, loss = 0.6624
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 122, loss = 0.6813
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 123, loss = 0.6610
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 124, loss = 0.6648
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 125, loss = 0.6644
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 126, loss = 0.6623
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 127, loss = 0.6613
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 128, loss = 0.6607
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 129, loss = 0.6625
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 130, loss = 0.6593
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 131, loss = 0.6592
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 132, loss = 0.6589
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 133, loss = 0.6583
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 134, loss = 0.6578
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 135, loss = 0.6574
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 136, loss = 0.6570
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 137, loss = 0.6566
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 138, loss = 0.6563
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 139, loss = 0.6560
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 140, loss = 0.6558
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 141, loss = 0.6556
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 142, loss = 0.6554
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 143, loss = 0.6553
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 144, loss = 0.6553
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 145, loss = 0.6550
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 146, loss = 0.6550
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 147, loss = 0.6549
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 148, loss = 0.6549
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 149, loss = 0.6549
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 150, loss = 0.6548
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 151, loss = 0.6548
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 152, loss = 0.6547
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 153, loss = 0.6547
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 154, loss = 0.6547
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 155, loss = 0.6547
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 156, loss = 0.6546
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 157, loss = 0.6546
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 158, loss = 0.6546
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 159, loss = 0.6546
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 160, loss = 0.6546
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 161, loss = 0.6546
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 162, loss = 0.6546
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 163, loss = 0.6546
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 164, loss = 0.6546
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 165, loss = 0.6546
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 166, loss = 0.6545
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 167, loss = 0.6545
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 168, loss = 0.6545
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 169, loss = 0.6545
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 170, loss = 0.6545
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 171, loss = 0.6545
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 172, loss = 0.6545
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# Step 173, loss = 0.6545
# Input: torch.Size([64, 976]) torch.int64 cpu
# Target: torch.Size([64]) torch.int64 cpu
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 14
#      12 loss = F.cross_entropy(logits, yb)
#      13 optimizer.zero_grad()
# ---> 14 loss.backward()
#      15 optimizer.step()
#      16 print(f"Step {step}, loss = {loss.item():.4f}")
#
# File ~/workspace/saturn/.venv/lib/python3.9/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/workspace/saturn/.venv/lib/python3.9/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/workspace/saturn/.venv/lib/python3.9/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
xb, yb = get_batch(4)
print("Target classes in batch:", yb.tolist())
assert 0 in yb and 1 in yb, "Need both classes for learning"

# %%
for name, param in model.named_parameters():
    print(name, param.device)
# Out:
# embedding.weight cpu
# lstm.weight_ih_l0 cpu
# lstm.weight_hh_l0 cpu
# lstm.bias_ih_l0 cpu
# lstm.bias_hh_l0 cpu
# fc.weight cpu
# fc.bias cpu

# %%
class MLPClassifier(nn.Module):
    def __init__(self, vocab_size, emb_dim, hidden_dim, num_classes, max_seq_len):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, emb_dim)
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(emb_dim * max_seq_len, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, num_classes)
        )

    def forward(self, x):
        x = self.embedding(x)  # (B, T, D)
        return self.net(x)

# %%
xb, yb = get_batch(10)
# xb = xb.to("cpu", dtype=torch.long)
# yb = yb.to("cpu", dtype=torch.long)

model = MLPClassifier(vocab_size, embedding_dim, hidden_size, 2, xb.shape[1])
model = model.to("cpu")


optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)

for step in range(200):
    logits = model(xb)
    loss = F.cross_entropy(logits, yb)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    preds = torch.argmax(logits, dim=1)
    print(f"Step {step}, loss = {loss.item():.4f}, preds = {preds.tolist()}, targets = {yb.tolist()}")
